# %% [markdown]
# # Mushroom Database:
#
# #### Attribute Information:
#      Target variable: (classes: edible=e, poisonous=p)
#      1. cap-shape:                bell=b,conical=c,convex=x,flat=f,
#                                   knobbed=k,sunken=s
#      2. cap-surface:              fibrous=f,grooves=g,scaly=y,smooth=s
#      3. cap-color:                brown=n,buff=b,cinnamon=c,gray=g,green=r,
#                                   pink=p,purple=u,red=e,white=w,yellow=y
#      4. bruises?:                 bruises=t,no=f
#      5. odor:                     almond=a,anise=l,creosote=c,fishy=y,foul=f,
#                                   musty=m,none=n,pungent=p,spicy=s
#      6. gill-attachment:          attached=a,descending=d,free=f,notched=n
#      7. gill-spacing:             close=c,crowded=w,distant=d
#      8. gill-size:                broad=b,narrow=n
#      9. gill-color:               black=k,brown=n,buff=b,chocolate=h,gray=g,
#                                   green=r,orange=o,pink=p,purple=u,red=e,
#                                   white=w,yellow=y
#     10. stalk-shape:              enlarging=e,tapering=t
#     11. stalk-root:               bulbous=b,club=c,cup=u,equal=e,
#                                   rhizomorphs=z,rooted=r,missing=?
#     12. stalk-surface-above-ring: fibrous=f,scaly=y,silky=k,smooth=s
#     13. stalk-surface-below-ring: fibrous=f,scaly=y,silky=k,smooth=s
#     14. stalk-color-above-ring:   brown=n,buff=b,cinnamon=c,gray=g,orange=o,
#                                   pink=p,red=e,white=w,yellow=y
#     15. stalk-color-below-ring:   brown=n,buff=b,cinnamon=c,gray=g,orange=o,
#                                   pink=p,red=e,white=w,yellow=y
#     16. veil-type:                partial=p,universal=u
#     17. veil-color:               brown=n,orange=o,white=w,yellow=y
#     18. ring-number:              none=n,one=o,two=t
#     19. ring-type:                cobwebby=c,evanescent=e,flaring=f,large=l,
#                                   none=n,pendant=p,sheathing=s,zone=z
#     20. spore-print-color:        black=k,brown=n,buff=b,chocolate=h,green=r,
#                                   orange=o,purple=u,white=w,yellow=y
#     21. population:               abundant=a,clustered=c,numerous=n,
#                                   scattered=s,several=v,solitary=y
#     22. habitat:                  grasses=g,leaves=l,meadows=m,paths=p,
#                                   urban=u,waste=w,woods=d

# %% [markdown]
# # Missing Attribute Values:
#     2480 of them (denoted by "?"), all for attribute #11.

# %% [markdown]
# # Class Distribution:
#     --    edible: 4208 (51.8%)
#     -- poisonous: 3916 (48.2%)
#     --     total: 8124 instances

# %% [markdown]
# # Sources:
#     (a) Mushroom records drawn from The Audubon Society Field Guide to North
#         American Mushrooms (1981). G. H. Lincoff (Pres.), New York: Alfred
#         A. Knopf
#     (b) Donor: Jeff Schlimmer (Jeffrey.Schlimmer@a.gp.cs.cmu.edu)
#     (c) Date: 27 April 1987

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # EDA

# %%
df = pd.read_csv("C:/Users/HP-PC/Desktop/Mashroom/mushrooms.csv")

# %%
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
df.replace("?",np.nan,inplace = True)

# %%
df.isna().sum()
# Out:
# class                          0
# cap-shape                      0
# cap-surface                    0
# cap-color                      0
# bruises                        0
# odor                           0
# gill-attachment                0
# gill-spacing                   0
# gill-size                      0
# gill-color                     0
# stalk-shape                    0
# stalk-root                  2480
# stalk-surface-above-ring       0
# stalk-surface-below-ring       0
# stalk-color-above-ring         0
# stalk-color-below-ring         0
# veil-type                      0
# veil-color                     0
# ring-number                    0
# ring-type                      0
# spore-print-color              0
# population                     0
# habitat                        0
# dtype: int64

# %%
df[ 'stalk-root'].unique()
# Out:
# array(['e', 'c', 'b', 'r', nan], dtype=object)

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %% [markdown]
# # Encoding the Data with Label Encoder converting all the catagorical data into numeric values.

# %%
from sklearn.preprocessing import LabelEncoder
LE= LabelEncoder()
catagorical_data = ['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
       'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
       'stalk-shape', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
       'ring-type', 'spore-print-color', 'population', 'habitat']

for i in catagorical_data:
    df[i]=df[i].astype('str')
    df[i]=LE.fit_transform(df[i])

# %%
df[ 'stalk-root'].replace("e",0, inplace = True)
df[ 'stalk-root'].replace("c",1, inplace = True)
df[ 'stalk-root'].replace("b",2, inplace = True)
df[ 'stalk-root'].replace("r",3, inplace = True)

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot = True, cmap = "coolwarm")
plt.show()

# %% [markdown]
# # key observation:
#      Veil type has no corelation we are droping the same
#      stalk-root and ring-type has higest negative corelation with 'spore-print-color' we will replace NAN values in stalk-root with the same.

# %%
df['spore-print-color'].unique()
# Out:
# array([2, 3, 6, 1, 7, 5, 4, 8, 0])

# %%
SPC_0= df.loc[df['spore-print-color']==0]
SPC_1= df.loc[df['spore-print-color']==1]
SPC_2= df.loc[df['spore-print-color']==2]
SPC_3= df.loc[df['spore-print-color']==3]
SPC_4= df.loc[df['spore-print-color']==4]
SPC_5= df.loc[df['spore-print-color']==5]
SPC_6= df.loc[df['spore-print-color']==6]
SPC_7= df.loc[df['spore-print-color']==7]
SPC_8= df.loc[df['spore-print-color']==8]

SPC_0[   'stalk-root'].replace(np.nan,SPC_0[   'stalk-root'].mean(), inplace = True)
SPC_1[   'stalk-root'].replace(np.nan,SPC_1[   'stalk-root'].mean(), inplace = True)
SPC_2[   'stalk-root'].replace(np.nan,SPC_2[   'stalk-root'].mean(), inplace = True)
SPC_3[   'stalk-root'].replace(np.nan,SPC_3[   'stalk-root'].mean(), inplace = True)
SPC_4[   'stalk-root'].replace(np.nan,SPC_4[   'stalk-root'].mean(), inplace = True)
SPC_5[   'stalk-root'].replace(np.nan,SPC_5[   'stalk-root'].mean(), inplace = True)
SPC_6[   'stalk-root'].replace(np.nan,SPC_6[   'stalk-root'].mean(), inplace = True)
SPC_7[   'stalk-root'].replace(np.nan,SPC_7[   'stalk-root'].mean(), inplace = True)
SPC_8[   'stalk-root'].replace(np.nan,SPC_8[   'stalk-root'].mean(), inplace = True)



df=SPC_0.append(
    SPC_1.append(
        SPC_2.append(
            SPC_3.append(
                SPC_4.append(
                    SPC_5.append(
                        SPC_6.append(
                            SPC_7.append(
                                SPC_8), ignore_index = True)))))))

# %%
rt_0= df.loc[df['ring-type']==0]
rt_1= df.loc[df['ring-type']==1]
rt_2= df.loc[df['ring-type']==2]
rt_3= df.loc[df['ring-type']==3]
rt_4= df.loc[df['ring-type']==4]


rt_0[   'stalk-root'].replace(np.nan,rt_0[   'stalk-root'].mean(), inplace = True)
rt_1[   'stalk-root'].replace(np.nan,rt_1[   'stalk-root'].mean(), inplace = True)
rt_2[   'stalk-root'].replace(np.nan,rt_2[   'stalk-root'].mean(), inplace = True)
rt_3[   'stalk-root'].replace(np.nan,rt_3[   'stalk-root'].mean(), inplace = True)
rt_4[   'stalk-root'].replace(np.nan,rt_4[   'stalk-root'].mean(), inplace = True)

df=rt_0.append(
    rt_1.append(
        rt_2.append(
            rt_3.append(
                rt_4),ignore_index = True)))

# %%
from sklearn.utils import shuffle
df = shuffle(df)
df.isna().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %% [markdown]
# # Classes variable is the target variable lets see the correleation with the same

# %%
plt.figure(figsize=(15,7))
df.corr()["class"].sort_values(ascending=False).drop(["class"]).plot.bar()
plt.xlabel("Feature", fontsize= 14)
plt.ylabel("correlation with Target column", fontsize = 18)
plt.title("Correlation of Fetures with the target column", fontsize=25)
plt.show()

# %% [markdown]
# # Key observation:
#     Veil - Type has no correlation
#     gill-size                    0.540024
#     population                   0.298686
#     habitat                      0.217179
#     stalk-root                   0.185250
#     cap-surface                  0.178446
#     spore-print-color            0.171961
#     veil-color                   0.145142
#     gill-attachment              0.129200
#     cap-shape                    0.052951
#     cap-color                   -0.031384
#     odor                        -0.093552
#     stalk-shape                 -0.102019
#     stalk-color-below-ring      -0.146730
#     stalk-color-above-ring      -0.154003
#     ring-number                 -0.214366
#     stalk-surface-below-ring    -0.298801
#     stalk-surface-above-ring    -0.334593
#     gill-spacing                -0.348387
#     ring-type                   -0.411771
#     bruises                     -0.501530
#     gill-color                  -0.530566

# %%
df = df.drop([ 'veil-type'], axis=1)

# %% [markdown]
# # Skeness Identification

# %%
plt.figure(figsize=(15,15))
collist = df.columns.values
for i in range (0, len(collist)):
    plt.subplot(6,4,i+1)         
    sns.kdeplot(df[collist[i]], color = "purple")
    plt.title(f"Skewness = {round(df[collist[i]].skew(),5)}",fontsize=15)
    plt.tight_layout()

# %%
skewness=[]
for i in df.skew().values:
    skewness.append(i)
    
df_skewness= pd.DataFrame({"Feature_names": collist,"Skew": skewness})
df_skewness= df_skewness.sort_values(by="Skew", ascending=False, ignore_index= True)


skew_postive_row= []
skew_negative_row=[]
for index, row in df_skewness.iterrows():
    if row['Skew']>0.49:
        skew_postive_row.append(row['Feature_names'])
    elif row['Skew']< -0.49:
        skew_negative_row.append(row['Feature_names'])
        
df_skewness
# Out:
#                Feature_names      Skew
# 0                ring-number  2.701657
# 1               gill-spacing  1.840088
# 2                    habitat  0.985548
# 3                  gill-size  0.825797
# 4                  cap-color  0.706965
# 5          spore-print-color  0.548426
# 6                    bruises  0.342750
# 7                      class  0.071946
# 8                 gill-color  0.061410
# 9                       odor -0.080790
# 10                 cap-shape -0.247052
# 11               stalk-shape -0.271345
# 12                 ring-type -0.290018
# 13               cap-surface -0.590859
# 14  stalk-surface-below-ring -0.757703
# 15  stalk-surface-above-ring -1.098739
# 16                stalk-root -1.309838
# 17                population -1.413096
# 18    stalk-color-below-ring -1.791593
# 19    stalk-color-above-ring -1.835434
# 20           gill-attachment -5.977076
# 21                veil-color -6.946944

# %%
print("\n\nFeature names with Skewness is present more than +/-0.5 as follows:\n","\n\nPostive Skewed data:\n", skew_postive_row,"\n\nnegative Skewed data:\n", skew_negative_row)
# Out:
# Feature names with Skewness is present more than +/-0.5 as follows:
#
#
# Postive Skewed data:
#  ['ring-number', 'gill-spacing', 'habitat', 'gill-size', 'cap-color', 'spore-print-color']
#
# negative Skewed data:
#  ['cap-surface', 'stalk-surface-below-ring', 'stalk-surface-above-ring', 'stalk-root', 'population', 'stalk-color-below-ring', 'stalk-color-above-ring', 'gill-attachment', 'veil-color']

# %%
df.skew().mean()
# Out:
# -0.6602682419124561

# %% [markdown]
# ##### Since the mean of skewnessof the whole data set is beyond -0.6602 we will not remove the skewness of the data.

# %% [markdown]
# # Lets Identify the Outliers

# %%
plt.figure(figsize=(15,50))
collist = df.columns.values
for i in range (0, len(collist)):
    plt.subplot(15,4,i+1)
    ax=sns.boxplot(df[collist[i]], color = "#696969" , orient = "h")
    ax.set_facecolor("#008fb3")
    plt.tight_layout()

# %% [markdown]
# # From the above observation its evident that the data have more outliers lets try in removing the outliers.

# %%
from scipy.stats import zscore
import numpy as np
z= np.abs(zscore(df))
threshold= 3
df_new = df[(z < 3).all(axis=1)]

# %%
print(f"Orginal Data {df.shape}\nAfter Removing outliers {df_new.shape}\nThe percentage of data loss {((8124-6568)/8124)*100}%")
# Out:
# Orginal Data (8124, 22)
# After Removing outliers (6568, 22)
# The percentage of data loss 19.15312653865091%

# %% [markdown]
# Post the Removal of outliers the loss of data is more lets try with IQR method

# %%
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3-Q1

df_new1=df[~((df<(Q1-1.5*IQR))|(df>(Q3+1.5*IQR))).any(axis=1)]
df_new1
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 3051      0          2            0          3        1     5
# 4030      0          5            3          3        1     5
# 5836      0          5            3          8        0     5
# 2685      0          2            0          4        1     5
# 1455      1          5            3          2        0     7
# ...     ...        ...          ...        ...      ...   ...
# 812       1          2            2          4        0     2
# 5773      0          2            3          6        0     5
# 1577      1          3            3          2        0     2
# 2634      0          2            3          2        1     5
# 2347      1          2            2          4        0     8
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 3051                1             0          0          10  ...
# 4030                1             0          0           5  ...
# ...

# %%
print(f"Orginal Data {df.shape}\nAfter Removing outliers {df_new1.shape}\nThe percentage of data loss {((8124-3088)/8124)*100}%")
# Out:
# Orginal Data (8124, 22)
# After Removing outliers (3088, 22)
# The percentage of data loss 61.98916789758739%

# %% [markdown]
# #### The loss of data is 20% in Z-Score method and 62% in IQR method which is pity bad and on removing the same will affect the performance of the data so we have to work with the outliers present in the data.

# %%
target_variable = "class"
feature_variable = [ 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
       'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
       'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring', 'veil-color', 'ring-number',
       'ring-type', 'spore-print-color', 'population', 'habitat']

def num_plots(feature_name):
    fig, axs = plt.subplots(1, 3, figsize=(20, 4))
    a1=sns.boxplot(x=df[feature_name], ax=axs[0], color="#696969")
    a1.set_facecolor("#3677c8")
    a2=sns.distplot(df[feature_name], bins=20, kde=True, ax=axs[1],color="#070907")
    a2.set_facecolor("#9cbce4")
    a3=sns.scatterplot(data=df, x=feature_name, y=target_variable, ax=axs[2], color="k")
    a3.set_facecolor("#008fb3")
    plt.show()
    
for i in feature_variable:
    num_plots(i)

# %%
x=df.drop(["class"], axis = 1)
y=df['class'].unique()

# %% [markdown]
# # Scaling the X variable

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X= sc.fit_transform(x)

# %% [markdown]
# # Selecting Parameter for Training

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report


accu = 0
for i in range(0,500):
    x_train, x_test, y_train, y_test = train_test_split(X,y,test_size = .25, random_state = i)
    mod = GaussianNB()
    mod.fit(x_train,y_train)
    y_pred = mod.predict(x_test)
    tempacc = accuracy_score(y_test,y_pred)
    if tempacc> accu:
        accu= tempacc
        best_rstate=i

print(f"Best Accuracy {accu*100} found on randomstate {best_rstate}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-2088c255880a> in <module>
#       7 accu = 0
#       8 for i in range(0,500):
# ----> 9     x_train, x_test, y_train, y_test = train_test_split(X,y,test_size = .25, random_state = i)
#      10     mod = GaussianNB()
#      11     mod.fit(x_train,y_train)
#
# E:\Anaconda\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2125         raise TypeError("Invalid parameters passed: %s" % str(options))
#    2126
# -> 2127     arrays = indexable(*arrays)
#    2128
#    2129     n_samples = _num_samples(arrays[0])
#
# E:\Anaconda\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     290     """
#     291     result = [_make_indexable(X) for X in iterables]
# --> 292     check_consistent_length(*result)
#     293     return result
#     294
#
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y,test_size = .25, random_state = best_rstate)

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import RandomizedSearchCV, cross_val_score 
from sklearn.model_selection import cross_validate, cross_val_predict, StratifiedKFold
from sklearn.feature_selection import RFECV
from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier, ExtraTreeClassifier
from sklearn import metrics
import xgboost as xgb

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Selecting the Best Classification Algorithm

# %%
def evaluate_model(estimator, x_train, y_train, cv=5, verbose=True):
   
    scoring = {"accuracy": "accuracy",
               "precision": "precision_weighted",
               "recall": "recall_weighted",
               "f1": "f1_weighted"}
    scores = cross_validate(estimator, x_train, y_train, cv=cv, scoring=scoring)
    
    accuracy, accuracy_std = scores['test_accuracy'].mean(), \
                                scores['test_accuracy'].std()
    
    precision, precision_std = scores['test_precision'].mean(), \
                                scores['test_precision'].std()
    
    recall, recall_std = scores['test_recall'].mean(), \
                                scores['test_recall'].std()
    
    f1, f1_std = scores['test_f1'].mean(), scores['test_f1'].std()

    
    result = {
        "Accuracy": accuracy,
        "Accuracy std": accuracy_std,
        "Precision": precision,
        "Precision std": precision_std,
        "Recall": recall,
        "Recall std": recall_std,
        "f1": f1,
        "f1 std": f1_std,
    }
    
    if verbose:
        print(f"Accuracy: {accuracy} - (std: {accuracy_std})")
        print(f"Precision: {precision} - (std: {precision_std})")
        print(f"Recall: {recall} - (std: {recall_std})")
        print(f"f1: {f1} - (std: {f1_std})")

    return result

# %%
models = [LogisticRegression(), GaussianNB(), KNeighborsClassifier(), RandomForestClassifier(random_state=42),
          DecisionTreeClassifier(random_state=42), ExtraTreeClassifier(random_state=42), 
          AdaBoostClassifier(random_state=42), GradientBoostingClassifier(random_state=42), 
          xgb.XGBClassifier()]

model_names = ["LogisticRegression", "Naive Bayes Gaussian", "K Neighbors Classifier", "Random Forest",
               "Decision Tree", "Extra Tree", "Ada Boost", 
               "Gradient Boosting", "XGBoost"]

# %%
accuracy = []
precision = []
recall = []
f1 = []

for model in range(len(models)):
    print(f"\n\nStep {model+1} of {len(models)}")
    print(f".........................running {model_names[model]}")
    
    clf_scores = evaluate_model(models[model], x_train, y_train)
    
    accuracy.append(clf_scores["Accuracy"])
    precision.append(clf_scores["Precision"])
    recall.append(clf_scores["Recall"])
    f1.append(clf_scores["f1"])

# %%
df_result = pd.DataFrame({"Model": model_names,
                          "accuracy": accuracy,
                          "precision": precision,
                          "recall": recall,
                          "f1": f1})
df_result.sort_values(by="f1", ascending=False)

# %%
metrics_list = ["f1", "accuracy", "precision", "recall"]

for metric in metrics_list:
    df_result.sort_values(by=metric).plot.bar("Model", metric, color = "#696969")
    plt.title(f"Model by {metric}")
    plt.show()

# %% [markdown]
# ### we have 6 Model tops the chart we will chose Random Forest and hypertune the same

# %%
clf_rf = RandomForestClassifier(random_state=42)
preds = cross_val_predict(clf_rf, x_train, y_train, cv=5, n_jobs=-1)

# %%
clf_rf.get_params()

# %%
pd.crosstab(y_train, preds, rownames = ['Real'], colnames =['Predicted'])

# %%
print(metrics.classification_report(y_train, preds, zero_division=0))

# %%
param_grid = [
    {"n_estimators": range(20, 200, 20), 
     "bootstrap": [True, False],
     "criterion": ["gini", "entropy"],   
     "max_depth": [2, 4, 6, 8, 10, 12, 14, None],
     "max_features": ["auto", "sqrt", "log2"], 
     "min_samples_split": [2, 5, 10],
     "min_samples_leaf": [1, 2, 4],
     }
]

clf_rf = RandomForestClassifier(random_state=42, n_jobs=-1)

# %%
clf_random = RandomizedSearchCV(clf_rf, param_grid, n_iter = 200, cv = 5, 
                                scoring="f1_weighted", verbose=2, 
                                random_state=42, n_jobs = -1)

# %%
clf_random.fit(x_train, y_train)

# %%
clf_random.best_params_

# %%
clf_random.best_score_

# %%
preds = cross_val_predict(clf_random.best_estimator_, x_train, y_train, cv=5, n_jobs=-1)
print(metrics.classification_report(y_train, preds, zero_division=0))

# %% [markdown]
# # Final fine-tune with GridSearch

# %%
param_grid = [
    {"n_estimators": range(20, 100, 10), 
     "bootstrap": [True, False],
     "criterion": ["gini", "entropy"],   
     "max_depth": [2, 4, 6, 8, 10, 12, 14, None],
     "max_features": ["auto", "sqrt", "log2"], 
     "min_samples_split": [2, 5, 10],
     "min_samples_leaf": [1, 2, 4],
     }
]


clf_rf = RandomForestClassifier(random_state=42, n_jobs=-1)

# %%
grid_search = GridSearchCV(clf_rf, param_grid, cv=5,
                           scoring="f1_weighted", verbose=2, n_jobs=-1)

# %%
grid_search.fit(x_train, y_train)

# %%
grid_search.best_params_

# %%
grid_search.best_score_

# %%
final_model = grid_search.best_estimator_
preds = cross_val_predict(final_model, x_train, y_train, cv=5, n_jobs=-1)
preds

# %%
pd.crosstab(y_train, preds, rownames = ['Actual'], colnames =['Predicted'])

# %%
print(metrics.classification_report(y_train, preds))

# %%
y_pred = final_model.predict(x_test)

pd.crosstab(y_test, y_pred, rownames = ['Actual'], colnames =['Predicted'])

# %%
print(metrics.classification_report(y_test, y_pred, zero_division=0))

# %%
conf_mx = metrics.confusion_matrix(y_test, y_pred)

# %%
fig = plt.figure(figsize=(8,8))
ax = sns.heatmap(conf_mx, annot=True, fmt="d", 
                 xticklabels=final_model.classes_,
                 yticklabels=final_model.classes_,
                cmap= "Blues")

# %% [markdown]
# # Feature importances¶

# %%
feature_importances = final_model.feature_importances_
feature_importances

# %%
selector = RFECV(final_model, step=1, cv=StratifiedKFold())
selector = selector.fit(x_train, y_train)

# %%
plt.figure(figsize=(15,7))
plt.xlabel("No. of features selected")
plt.ylabel("Cross validation scores")
plt.plot(range(1, len(selector.grid_scores_) + 1), selector.grid_scores_)
plt.show()

# %%
selector.grid_scores_

# %% [markdown]
# # Saving the final model

# %%
import joblib
joblib.dump(final_model,"C:/Users/HP-PC/Desktop/MashroomMush.obj")

# %%
Mush= joblib.load('C:/Users/HP-PC/Desktop/MashroomMush.obj')
prediction = Mush.predict(x_test)
prediction

# %%
print("Model Score test data :" ,Mush.score(x_test,y_test))

# %%
print("Accuracy score is :",accuracy_score(y_test,prediction))
